# %%
 # !pip install torch torchvision matplotlib seaborn scikit-learn

# %%
from google.colab import files
import zipfile
import os

uploaded = files.upload()
for fn in uploaded.keys():
    print(f'Загружен файл: {fn}')
    with zipfile.ZipFile(fn, 'r') as zip_ref:
        zip_ref.extractall('/content/')
print('Данные распакованы!')
print(os.listdir('/content/music_instruments'))
# Out:
#      <input type="file" id="files-fb1e33d5-b4e4-4570-86de-a7f1bd4c29a8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fb1e33d5-b4e4-4570-86de-a7f1bd4c29a8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split, Dataset
from torchvision import transforms, datasets
import matplotlib.pyplot as plt
import numpy as np
import os
import seaborn as sns
from sklearn.metrics import confusion_matrix

# %%
IMG_SIZE = 128
BATCH_SIZE = 32
EPOCHS = 30  # Увеличено количество эпох по запросу
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
train_transform = transforms.Compose([

    transforms.Resize((128,128)),

    transforms.RandomHorizontalFlip(),

    transforms.RandomRotation(10),

    transforms.RandomAffine(
        degrees=0,
        translate=(0.1,0.1)
    ),

    transforms.ColorJitter(
        brightness=0.2,
        contrast=0.2
    ),

    transforms.ToTensor(),

    transforms.Normalize(
        [0.485, 0.456, 0.406],
        [0.229, 0.224, 0.225]
    )
])
full_dataset = datasets.ImageFolder(root='/content/music_instruments', transform=None)
train_size = int(0.8 * len(full_dataset))
val_size = len(full_dataset) - train_size
train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

# %%
train_dataset.dataset.transform = train_transform
val_dataset.dataset.transform = val_transform

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=2)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)

print(f"Найдено классов: {len(train_dataset.dataset.classes)} -> {train_dataset.dataset.classes}")
# Out:
# Найдено классов: 10 -> ['accordion', 'banjo', 'drum', 'flute', 'guitar', 'harmonica', 'saxophone', 'sitar', 'tabla', 'violin']

# %%
def show_images(images, labels, class_names, title='Examples'):
    plt.figure(figsize=(15,10))
    for i in range(9):
        plt.subplot(3,3,i+1)
        img = images[i].numpy().transpose((1, 2, 0))
        img = img * np.array([0.229, 0.224, 0.225]) + np.array([0.485, 0.456, 0.406])
        img = np.clip(img, 0, 1)
        plt.imshow(img)
        plt.title(f"True: {class_names[labels[i]]}")
        plt.axis('off')
    plt.suptitle(title)
    plt.tight_layout()
    plt.show()

images, labels = next(iter(train_loader))
# Access .classes from the underlying original dataset
class_names = train_dataset.dataset.classes
show_images(images, labels, class_names, title='Train Examples')

# %%
class MusicCNN(nn.Module):

    def __init__(self, num_classes=10):

        super(MusicCNN, self).__init__()

        self.features = nn.Sequential(

            nn.Conv2d(3, 32, 3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(32, 64, 3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(64, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(128, 256, 3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )

        self.classifier = nn.Sequential(

            nn.Flatten(),

            nn.Linear(256 * 8 * 8, 256),

            nn.ReLU(),

            nn.Dropout(0.3),

            nn.Linear(256, num_classes)
        )

    def forward(self, x):

        x = self.features(x)

        x = self.classifier(x)

        return x

# %%
model = MusicCNN(
    num_classes=len(train_dataset.dataset.classes)
).to(DEVICE)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

train_losses, val_losses = [], []
train_accs, val_accs = [], []

# EARLY STOPPING
best_val_loss = float('inf')
patience = 5
counter = 0

for epoch in range(EPOCHS):


    model.train()

    running_loss, correct, total = 0.0, 0, 0

    for images, labels in train_loader:

        images, labels = images.to(DEVICE), labels.to(DEVICE)

        optimizer.zero_grad()

        outputs = model(images)

        loss = criterion(outputs, labels)

        loss.backward()

        optimizer.step()

        running_loss += loss.item()

        _, predicted = outputs.max(1)

        correct += predicted.eq(labels).sum().item()

        total += labels.size(0)

    train_losses.append(running_loss / total)
    train_accs.append(correct / total)


    model.eval()

    val_loss, val_correct, val_total = 0.0, 0, 0

    with torch.no_grad():

        for images, labels in val_loader:

            images, labels = images.to(DEVICE), labels.to(DEVICE)

            outputs = model(images)

            loss = criterion(outputs, labels)

            val_loss += loss.item()

            _, predicted = outputs.max(1)

            val_correct += predicted.eq(labels).sum().item()

            val_total += labels.size(0)

    val_losses.append(val_loss / val_total)
    val_accs.append(val_correct / val_total)

    print(
        f"Epoch {epoch+1}/{EPOCHS} | "
        f"Train Loss: {train_losses[-1]:.4f} Acc: {train_accs[-1]:.4f} | "
        f"Val Loss: {val_losses[-1]:.4f} Acc: {val_accs[-1]:.4f}"
    )


    if val_losses[-1] < best_val_loss:

        best_val_loss = val_losses[-1]

        counter = 0

        torch.save(model.state_dict(), 'best_model.pth')

        print("Validation loss improved. Model saved.")

    else:

        counter += 1

        print(f"No improvement for {counter} epoch(s)")

        if counter >= patience:

            print("Early stopping triggered!")

            break
# Out:
# Epoch 1/30 | Train Loss: 0.1003 Acc: 0.2154 | Val Loss: 0.0615 Acc: 0.3370
# Validation loss improved. Model saved.
# Epoch 2/30 | Train Loss: 0.0573 Acc: 0.3476 | Val Loss: 0.0568 Acc: 0.4116
# Validation loss improved. Model saved.
# Epoch 3/30 | Train Loss: 0.0535 Acc: 0.3961 | Val Loss: 0.0542 Acc: 0.4641
# Validation loss improved. Model saved.
# Epoch 4/30 | Train Loss: 0.0501 Acc: 0.4363 | Val Loss: 0.0512 Acc: 0.4834
# Validation loss improved. Model saved.
# Epoch 5/30 | Train Loss: 0.0477 Acc: 0.4765 | Val Loss: 0.0499 Acc: 0.4862
# Validation loss improved. Model saved.
# Epoch 6/30 | Train Loss: 0.0441 Acc: 0.5319 | Val Loss: 0.0434 Acc: 0.5912
# Validation loss improved. Model saved.
# Epoch 7/30 | Train Loss: 0.0423 Acc: 0.5436 | Val Loss: 0.0444 Acc: 0.5552
# No improvement for 1 epoch(s)
# Epoch 8/30 | Train Loss: 0.0398 Acc: 0.5665 | Val Loss: 0.0468 Acc: 0.5249
# No improvement for 2 epoch(s)
# ...

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(train_accs, label='Train Accuracy')
plt.plot(val_accs, label='Val Accuracy')
plt.legend()
plt.title('Accuracy')
plt.subplot(1,2,2)
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Val Loss')
plt.legend()
plt.title('Loss')
plt.tight_layout()
plt.show()

# %%
model.eval()
all_preds, all_labels = [], []
with torch.no_grad():
    for images, labels in val_loader:
        images, labels = images.to(DEVICE), labels.to(DEVICE)
        preds = model(images).max(1)[1]
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(10,8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# %%
model.eval()
images, labels = next(iter(val_loader))
images, labels = images.to(DEVICE), labels.to(DEVICE)
preds = model(images).max(1)[1]

plt.figure(figsize=(15,10))
for i in range(9):
    plt.subplot(3,3,i+1)
    img = images[i].cpu().numpy().transpose((1, 2, 0))
    img = img * np.array([0.229, 0.224, 0.225]) + np.array([0.485, 0.456, 0.406])
    img = np.clip(img, 0, 1)
    plt.imshow(img)
    true_name = train_dataset.dataset.classes[labels[i]]
    pred_name = train_dataset.dataset.classes[preds[i]]
    plt.title(f"True: {true_name}\nPred: {pred_name}")
    plt.axis('off')
plt.tight_layout()
plt.show()
